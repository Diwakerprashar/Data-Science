# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
colours = ['Red','Green','yellow','Purple','Black']

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
g = df.groupby('Location')[['MinTemp','MaxTemp','Rainfall']].mean()

# %%
df.groupby('Location')[['MinTemp','MaxTemp','Rainfall','WindGustSpeed']].mean()
# Out:
#                     MinTemp    MaxTemp  Rainfall  WindGustSpeed
# Location
# Adelaide          12.579505  22.898934  1.566354      36.499211
# Albany            12.948438  20.070998  2.263859            NaN
# Albury             9.530604  22.640872  1.914115      32.977394
# AliceSprings      13.142284  29.248420  0.882850      40.531281
# BadgerysCreek     11.131719  24.031208  2.193101      33.600409
# Ballarat           7.367950  18.287266  1.740026      44.982719
# Bendigo            8.593713  21.621746  1.619380      38.850000
# Brisbane          16.423807  26.448380  3.144891      28.212881
# Cairns            21.220467  29.558849  5.742035      38.031436
# Canberra           6.821866  20.976639  1.741720      40.064214
# Cobar             13.149451  25.870093  1.127309      36.750590
# CoffsHarbour      14.437108  23.965385  5.061497      39.227925
# Dartmoor           8.620034  19.697454  2.146567      38.898299
# ...

# %%
Rmax = g['Rainfall'].nlargest(5)
print(Rmax.index)
print(Rmax.values)
# Out:
# Index(['Cairns', 'Darwin', 'CoffsHarbour', 'GoldCoast', 'Wollongong'], dtype='object', name='Location')
# [5.74203481 5.09245224 5.06149678 3.76939597 3.59490275]

# %%
fig = plt.figure(figsize = [8,6])
axes = fig.add_axes([0.1,0.1,1,0.8])
axes.bar(Rmax.index,Rmax.values,width = 0.6,color = colours)
plt.title('Maximum Rainfall Locations',fontsize = 20)
plt.xlabel('Locations',fontsize=20)
plt.ylabel('Max Rainfall.',fontsize = 20)
# Out:
# Text(0, 0.5, 'Max Rainfall.')

# %%
Rmin = g['Rainfall'].nsmallest(5)
print(Rmin.index)
print(Rmin.values)
# Out:
# Index(['Woomera', 'Uluru', 'AliceSprings', 'Nhil', 'Mildura'], dtype='object', name='Location')
# [0.49040455 0.78436268 0.8828496  0.93486297 0.94506152]

# %%
fig = plt.figure(figsize = [8,6])
axes = fig.add_axes([0.1,0.1,1,0.8])
axes.bar(Rmin.index,Rmin.values,width = 0.6,color = colours)
plt.title('Minimum Rainfall Locations',fontsize = 20)
plt.xlabel('Locations',fontsize=20)
plt.ylabel('Min Rainfall.',fontsize = 20)
# Out:
# Text(0, 0.5, 'Min Rainfall.')

# %%
T = g['MaxTemp'].nlargest(5)
print(T.index,T.values)
# Out:
# Index(['Katherine', 'Darwin', 'Uluru', 'Cairns', 'Townsville'], dtype='object', name='Location') [34.93543563 32.54097744 30.38319542 29.55884868 29.36716025]

# %%
fig = plt.figure(figsize = [8,6])
axes = fig.add_axes([0.1,0.1,1,0.8])
axes.bar(T.index,T.values,width = 0.6,color = colours)
plt.title('Maximum Temperature Locations',fontsize = 20)
plt.xlabel('Locations',fontsize=20)
plt.ylabel('Max Temp.',fontsize = 20)
# Out:
# Text(0, 0.5, 'Max Temp.')

# %%
print('Max Temp',T.values)
print('Max Rain',Rmax.values)
print(T)
print(Rmax)
# Out:
# Max Temp [34.93543563 32.54097744 30.38319542 29.55884868 29.36716025]
# Max Rain [5.74203481 5.09245224 5.06149678 3.76939597 3.59490275]
# Location
# Katherine     34.935436
# Darwin        32.540977
# Uluru         30.383195
# Cairns        29.558849
# Townsville    29.367160
# Name: MaxTemp, dtype: float64
# Location
# Cairns          5.742035
# Darwin          5.092452
# CoffsHarbour    5.061497
# GoldCoast       3.769396
# Wollongong      3.594903
# Name: Rainfall, dtype: float64

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['Avg_Humidity'] = (df['Humidity9am'] + df['Humidity3pm'])/2

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# ...

# %%
print(Rmax.index,'Max Rain',Rmax.values)
# Out:
# Index(['Cairns', 'Darwin', 'CoffsHarbour', 'GoldCoast', 'Wollongong'], dtype='object', name='Location') Max Rain [5.74203481 5.09245224 5.06149678 3.76939597 3.59490275]

# %%
a = df.groupby('Location')['Avg_Humidity'].mean()
w = df.groupby('Location')['WindGustSpeed'].mean()

# %%
sns.kdeplot(a)

# %%
sns.kdeplot(w)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.jointplot(x = 'Avg_Humidity',y = 'Rainfall',data = df,kind = 'scatter')

# %%
sns.jointplot(x = 'Avg_Humidity',y = 'Rainfall',data = df,kind = 'reg')

# %%
tc = df.corr()

# %%
fig = plt.figure(figsize=[10,6])
axes = fig.add_axes([0.1,0.1,1,0.8])
sns.heatmap(tc,cmap='magma',linewidths=0.8)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...
